# %%
] st
# Out:
# Project Jules v0.1.0
#     Status `~/Development/julia/Jules/Project.toml`
#   [c7e460c6] ArgParse v0.6.2+ [`dev/ArgParse`]
#   [7057c7e9] Cassette v0.2.3
#   [a0b5b9ef] Cxx v0.2.0+ [`dev/Cxx`]
#   [8f5d6c58] EzXML v0.9.1
#   [cd3eb016] HTTP v0.8.0
#   [0e44f5e4] Hwloc v1.0.0
#   [7073ff75] IJulia v1.18.0
#   [62f30a8c] Init v0.1.0 [`dev/Init`]
#   [682c06a0] JSON v0.20.0
#   [1914dd2f] MacroTools v0.5.0
#   [9b87118b] PackageCompiler v0.6.3
#   [3349acd9] ProtoBuf v0.7.0
#   [c2297ded] ZMQ v1.0.0
#   [8ba89e20] Distributed
#   [76f85450] LibGit2

# %%
macro p(expr)
    e = macroexpand(__module__, esc(expr))
    e_str = repr(macroexpand(__module__, expr))
    quote
        println($(e_str))
        result = $(e)
        println("\n")
        result
    end
end
# Out:
# @p (macro with 1 method)

# %%
@p print(:(a=2))
@p print("2")
@p dump(Expr)
# Out:
# :(print($(Expr(:copyast, :($(QuoteNode(:(a = 2))))))))
# a = 2
#
# :(print("2"))
# 2
#
# :(dump(Expr))
# Expr <: Any
#   head::Symbol
#   args::Array{Any,1}

# %%
using Jules.Log

function print_expr(io::IO, args::Vector)
    if length(args) == 0
        print(io, "()")
        return
    end
    
    println(io, "(")
    indent(io) do io::IO
        for i in eachindex(args)
            print_expr(io, args[i])
            println(io, ",")
        end
    end
    indent(io)
    print(io, ")")
end
function print_expr(io::IO, args::Vector{Symbol})
    show(io, tuple(args...))
end
function print_expr(io::IO, expr::Expr)
    print_expr(io, expr.head)
    args = [arg for arg in expr.args if !isa(arg, LineNumberNode)]
    print_expr(io, args)
end
print_expr(io::IO, expr) = (indent(io); show(io, expr))
print_expr(io::IO, sym::Symbol) = (indent(io); print(io, sym))
print_expr(io::IO, ::LineNumberNode) = nothing
print_expr(expr) = print_expr(Base.stdout, expr)

info(expr) = begin
    @p show(expr)
    @p Meta.show_sexpr(expr)
    @p print_expr(expr)
end
# Out:
# ┌ Info: Recompiling stale cache file /Users/layne/.julia/compiled/v1.1/Jules/Rvud4.ji for Jules [75c68590-e1fc-11e8-3994-2111e53accda]
# └ @ Base loading.jl:1184
# WARNING: Method definition show(IO, EzXML.Node) in module EzXML at /Users/layne/.julia/packages/EzXML/r19gO/src/node.jl:299 overwritten in module Xml at /Users/layne/Development/julia/Jules/src/Xml/fromxml.jl:23.
# info (generic function with 1 method)

# %%
expr = quote
    abstract type Interface{T} end
    struct Implementation{T} <: Interface{T}
        t::T
    end
    mutable struct MutableImplementation{T} <: Interface{T}
        t::T
    end
end

info(expr)
# Out:
# :(show(expr))
# quote
#     #= In[5]:2 =#
#     abstract type Interface{T} end
#     #= In[5]:3 =#
#     struct Implementation{T} <: Interface{T}
#         #= In[5]:4 =#
#         t::T
#     end
#     #= In[5]:6 =#
#     mutable struct MutableImplementation{T} <: Interface{T}
#         #= In[5]:7 =#
#         t::T
#     end
# end
#
# :(Meta.show_sexpr(expr))
# (:block,
#   :(#= In[5]:2 =#),
#   (:abstract, (:curly, :Interface, :T)),
#   :(#= In[5]:3 =#),
#   (:struct, false, (:<:, (:curly, :Implementation, :T), (:curly, :Interface, :T)), (:block,
#       :(#= In[5]:4 =#),
#       (:(::), :t, :T)
#     )),
#   :(#= In[5]:6 =#),
#   (:struct, true, (:<:, (:curly, :MutableImplementation, :T), (:curly, :Interface, :T)), (:block,
#       :(#= In[5]:7 =#),
#       (:(::), :t, :T)
#     ))
# )
#
# :(print_expr(expr))
# block(
#   abstract(
#     curly(:Interface, :T),
#   ),
#   struct(
#     false,
#     <:(
#       curly(:Implementation, :T),
#       curly(:Interface, :T),
#     ),
#     block(
#       ::(:t, :T),
#     ),
#   ),
#   struct(
#     true,
#     <:(
#       curly(:MutableImplementation, :T),
#       curly(:Interface, :T),
#     ),
#     block(
#       ::(:t, :T),
#     ),
#   ),
# )

# %%
expr = quote
    function stuff(interface::Interface{T}) where T<:Int
        println("int stuff")
    end
    function stuff(interface::Interface{T} where T<:String)
        println("string stuff")
    end
end

info(expr)
# Out:
# :(show(expr))
# quote
#     #= In[6]:2 =#
#     function stuff(interface::Interface{T}) where T <: Int
#         #= In[6]:3 =#
#         println("int stuff")
#     end
#     #= In[6]:5 =#
#     function stuff(interface::(Interface{T} where T <: String))
#         #= In[6]:6 =#
#         println("string stuff")
#     end
# end
#
# :(Meta.show_sexpr(expr))
# (:block,
#   :(#= In[6]:2 =#),
#   (:function, (:where, (:call, :stuff, (:(::), :interface, (:curly, :Interface, :T))), (:<:, :T, :Int)), (:block,
#       :(#= In[6]:3 =#),
#       (:call, :println, "int stuff")
#     )),
#   :(#= In[6]:5 =#),
#   (:function, (:call, :stuff, (:(::), :interface, (:where, (:curly, :Interface, :T), (:<:, :T, :String)))), (:block,
#       :(#= In[6]:6 =#),
#       (:call, :println, "string stuff")
#     ))
# )
#
# :(print_expr(expr))
# block(
#   function(
#     where(
#       call(
#         stuff,
#         ::(
#           interface,
#           curly(:Interface, :T),
#         ),
#       ),
#       <:(:T, :Int),
#     ),
#     block(
#       call(
#         println,
#         "int stuff",
#       ),
#     ),
#   ),
#   function(
#     call(
#       stuff,
#       ::(
#         interface,
#         where(
#           curly(:Interface, :T),
#           <:(:T, :String),
#         ),
#       ),
#     ),
#     block(
#       call(
#         println,
#         "string stuff",
#       ),
#     ),
#   ),
# )

# %%
import Base: show

expr_types = quote
    abstract type Node end
    abstract type TypedExpr{T} <: Node end
    struct ValExpr{T} <: TypedExpr{T}
        val::T
    end
    struct SymbolExpr{T} <: TypedExpr{T}
        SymbolExpr(sym::Symbol) = new{sym}()
    end
    struct BasicExpr{T} <: TypedExpr{T}
        args::Vector{<:Node}
    end
    struct InfixExpr{T} <: TypedExpr{T}
        args::Vector{<:Node}
    end
    struct CallExpr{T} <: TypedExpr{T}
        head::TypedExpr{T}
        args::Vector{<:Node}
        
        function CallExpr(head::TypedExpr{T}, args) where T
            a2 = [arg for arg in args]
            new{T}(head, a2)
        end
    end
    struct QuoteExpr{T} <: TypedExpr{T}
        val::T
    end
end
expr_parse = quote
    function parse_args(args::Vector)
        args = [arg for arg in args if !isa(arg, LineNumberNode)]
        return map(parse, args)
    end
    function parse(::SymbolExpr{T}, args::Node...) where T
        return BasicExpr{T}([args...])
    end
    function parse(::SymbolExpr{:call}, head::TypedExpr{T}, args::Node...) where T
        return CallExpr(head, args)
    end
    parse(expr::Expr) = parse(SymbolExpr(expr.head), parse_args(expr.args)...)
    parse(sym::Symbol) = SymbolExpr(sym)
    parse(node::QuoteNode) = QuoteExpr(node.value)
    parse(arg) = ValExpr(arg)
end
for op = (:(==), :(!==), :(<=), :(>=), :(<), :(>))
    node = QuoteNode(op)
    ex = quote
        function parse(::SymbolExpr{:call}, head::SymbolExpr{$node}, args::Node...)
            return InfixExpr{$node}([args...])
        end
    end
    push!(expr_parse.args, ex.args...)
end
expr_show = quote
    show(io::IO, args::Vector; start='(', stop=')') = begin
        print(io, start)
        if length(args) <= 1
            for arg in args
                show(io, arg)
            end
            print(io, stop)
            return
        end
        if length(args) == 2
            show(io, args[1])
            print(io, ", ")
            show(io, args[2])
            print(io, stop)
            return
        end
        
        println(io)
        indent(io) do io::IO
            indent(io)
            show(io, args[1])
            for arg in args[2:end]
                println(io, ",")
                indent(io)
                show(io, arg)
            end
            println(io)
        end
        indent(io)
        print(io, stop)
    end
    show_args(io::IO, args::Node...) = begin
        if length(args) == 0
            return
        end
        if length(args) == 1
            show(io, args[1])
            return
        end
        show(io, [args...])
    end
    show_div(io::IO, expr::BasicExpr{T}) where T = begin
        args = expr.args
        if length(args) > 1
            show(io, args[1])
            args = args[2:end]
        end
        print(io, T)
        show_args(io, args...)
    end
    show_block(io::IO, blk::BasicExpr{:block}) = begin
        println(io)
        indent(io) do io::IO
            for arg in blk.args
                indent(io)
                show(io, arg)
                println(io)
            end
        end
        indent(io)
        print(io, "end")
    end
    show_vect(io::IO, args::Vector) = begin
        print(io, "[")
        show_args(io, args...)
        print(io, "]")
    end
    show_infix(io::IO, head::Any, args::Vector) = begin
        show(io, args[1])
        print(io, " ", head, " ")
        show_args(io, args[2:end]...)
    end
    show(io::IO, node::QuoteExpr) = show(io, node.val)
    show(io::IO, expr::ValExpr) = show(io, expr.val)
    show(io::IO, expr::SymbolExpr{T}) where T = print(io, T)
    show(io::IO, expr::BasicExpr{T}) where T = begin
        show(io, T)
        args = [arg for arg in expr.args if !isa(arg, LineNumberNode)]
        show(io, args)
    end
    show(io::IO, expr::BasicExpr{:block}) = begin
        print(io, "begin")
        show_block(io, expr)
    end
    show(io::IO, expr::InfixExpr{T}) where T = show_infix(io, T, expr.args)
    show(io::IO, expr::CallExpr) = begin
        show(io, expr.head)
        args = expr.args
        kwargs = nothing
        if length(args) > 0 && args[1] isa BasicExpr{:parameters}
            kwargs = args[1].args
            args = args[2:end]
        end
        print(io, '(')
        show(io, args; start = "", stop="")
        if kwargs !== nothing
            print(io, "; ")
            show(io, kwargs; start="", stop="")
        end
        print(io, ')')
    end
    show(io::IO, expr::CallExpr{:(:)}) = begin
        args = expr.args
        if length(args) == 0
            # TODO: not sure
            args = expr.args[:]
            print(io, ":")
            return
        end
        show(io, args[1])
        print(io, ":")
        show_args(io, args[2:end]...)
    end
    show(io::IO, expr::CallExpr{:(!)}) = begin
        print(io, "!")
        show_args(io, expr.args...)
    end
    show(io::IO, expr::BasicExpr{:(::)}) = show_div(io, expr)
    show(io::IO, expr::BasicExpr{:curly}) = begin
        show(io, expr.args[1])
        show(io, expr.args[2:end]; start='{', stop='}')
    end
    show(io::IO, expr::BasicExpr{:where}) = begin
        show(io, expr.args[1])
        print(io, " where ")
        show(io, expr.args[2:end]; start='{', stop='}')
    end
    show(io::IO, expr::BasicExpr{:function}) = begin
        print(io, "function ")
        show(io, expr.args[1])
        show_block(io, expr.args[2])
    end
    show(io::IO, expr::BasicExpr{:.}) = begin
        args = expr.args
        @assert length(args) == 2
        show(io, args[1])
        print(io, ".")
        node = args[2]
        if isa(node, QuoteExpr)
            args[2] = parse(node.val)
        end
        show(io, args[2])
    end
    show(io::IO, expr::BasicExpr{:...}) = begin
        args = expr.args
        @assert length(args) == 1
        show(io, args[1])
        print(io, "...")
    end
    show(io::IO, expr::BasicExpr{:ref}) = begin
        args = expr.args
        @assert length(args) == 2
        show(io, args[1])
        print(io, "[")
        show(io, args[2])
        print(io, "]")
    end
    show(io::IO, expr::BasicExpr{:vect}) = begin
        show_vect(io, expr.args)
    end
    show(io::IO, expr::BasicExpr{:return}) = begin
        print(io, "return ")
        show_args(io, expr.args...)
    end
    show(io::IO, expr::BasicExpr{:do}) = begin
        args = expr.args
        @assert length(args) == 2
        show(io, args[1])
        print(io, " do ")
        show(io, args[2])
    end
    show(io::IO, expr::BasicExpr{:->}) = begin
        args = expr.args
        @assert length(args) == 2
        arg = args[1]
        if isa(arg, BasicExpr{:tuple})
            show_args(io, arg.args...)
            arg = nothing
        end
        if arg !== nothing
            show(io, arg)
        end
        show_block(io, args[2])
    end
    show(io::IO, expr::BasicExpr{:tuple}) = begin
        args = expr.args
        if length(args) > 1
            show(io, args)
            return
        end
        
        print(io, "(")
        for arg in args
            show(io, arg)
            print(io, ",")
        end
        print(io, ")")
    end
    show(io::IO, expr::BasicExpr{:for}) = begin
        args = expr.args
        print(io, "for ")
        show(io, args[1])
        show_block(io, args[2])
    end
    show(io::IO, expr::BasicExpr{:comprehension}) = begin
        show_vect(io, expr.args)
    end
    show(io::IO, expr::BasicExpr{:generator}) = begin
        args = expr.args
        show(io, args[1])
        print(io, " for ")
        show_args(io, args[2:end]...)
    end
    show(io::IO, expr::BasicExpr{:filter}) = begin
        args = expr.args
        @assert length(args) == 2
        show(io, args[2])
        print(io, " if ")
        show(io, args[1])
    end
    show(io::IO, expr::BasicExpr{:abstract}) = begin
        print(io, "abstract type ")
        show_args(io, expr.args...)
        println(io)
        print(io, "end")
    end
    show(io::IO, expr::BasicExpr{:struct}) = begin
        args = expr.args
        @assert length(args) == 3
        mu = args[1]::ValExpr{Bool}
        if mu.val
            print(io, "mutable ")
        end
        print(io, "struct ")
        show(io, args[2])
        show_block(io, args[3])
    end
    show(io::IO, expr::BasicExpr{:kw}) = begin
        args = expr.args
        @assert length(args) == 2
        show(io, args[1])
        print(io, "=")
        show(io, args[2])
    end
end
for op in (:(<:), :(>:), :(=), :(&&), :(||))
    node = QuoteNode(op)
    ex = quote
        show(io::IO, expr::BasicExpr{$node}) = begin
            if length(expr.args) <= 1
                show_div(io, expr)
                return
            end
            show_infix(io, $node, expr.args)
        end
    end
    push!(expr_show.args, ex.args...)
end

# @p print_expr(expr)
# @p eval(expr)

expr = Expr(:block, expr_types.args..., expr_parse.args..., expr_show.args...)
eval(expr)

blk = parse(expr)
for arg in blk.args
    show(arg)
    print("\n\n")
end
# Out:
# abstract type Node
# end
#
# abstract type TypedExpr{T} <: Node
# end
#
# struct ValExpr{T} <: TypedExpr{T}
#   val::T
# end
#
# struct SymbolExpr{T} <: TypedExpr{T}
#   SymbolExpr(sym::Symbol) = begin
#     new{sym}()
#   end
# end
#
# struct BasicExpr{T} <: TypedExpr{T}
#   args::Vector{<:Node}
# end
#
# struct InfixExpr{T} <: TypedExpr{T}
#   args::Vector{<:Node}
# end
#
# struct CallExpr{T} <: TypedExpr{T}
#   head::TypedExpr{T}
#   args::Vector{<:Node}
#   function CallExpr(head::TypedExpr{T}, args) where {T}
#     a2 = [arg for arg = args]
#     new{T}(head, a2)
#   end
# end
#
# struct QuoteExpr{T} <: TypedExpr{T}
#   val::T
# end
#
# function parse_args(args::Vector)
#   args = [arg for arg = args if !isa(arg, LineNumberNode)]
#   return map(parse, args)
# end
#
# function parse(::SymbolExpr{T}, args::Node...) where {T}
#   return BasicExpr{T}([args...])
# end
#
# function parse(
#   ::SymbolExpr{:call},
#   head::TypedExpr{T},
#   args::Node...
# ) where {T}
#   return CallExpr(head, args)
# end
#
# parse(expr::Expr) = begin
#   parse(SymbolExpr(expr.head), parse_args(expr.args)...)
# end
#
# parse(sym::Symbol) = begin
#   SymbolExpr(sym)
# end
#
# parse(node::QuoteNode) = begin
#   QuoteExpr(node.value)
# end
#
# parse(arg) = begin
#   ValExpr(arg)
# end
#
# function parse(
#   ::SymbolExpr{:call},
#   head::SymbolExpr{:(==)},
#   args::Node...
# )
#   return InfixExpr{:(==)}([args...])
# end
#
# function parse(
#   ::SymbolExpr{:call},
#   head::SymbolExpr{:!==},
#   args::Node...
# )
#   return InfixExpr{:!==}([args...])
# end
#
# function parse(
#   ::SymbolExpr{:call},
#   head::SymbolExpr{:<=},
#   args::Node...
# )
#   return InfixExpr{:<=}([args...])
# end
#
# function parse(
#   ::SymbolExpr{:call},
#   head::SymbolExpr{:>=},
#   args::Node...
# )
#   return InfixExpr{:>=}([args...])
# end
#
# function parse(
#   ::SymbolExpr{:call},
#   head::SymbolExpr{:<},
#   args::Node...
# )
#   return InfixExpr{:<}([args...])
# end
#
# function parse(
#   ::SymbolExpr{:call},
#   head::SymbolExpr{:>},
#   args::Node...
# )
#   return InfixExpr{:>}([args...])
# end
#
# show(io::IO, args::Vector; start='(', stop=')') = begin
#   print(io, start)
#   :if(length(args) <= 1, begin
#     for arg = args
#       show(io, arg)
#     end
#     print(io, stop)
#     return nothing
#   end)
#   :if(length(args) == 2, begin
#     show(io, args[1])
#     print(io, ", ")
#     show(io, args[2])
#     print(io, stop)
#     return nothing
#   end)
#   println(io)
#   indent(io) do io::IO
#     indent(io)
#     show(io, args[1])
#     for arg = args[2:end]
#       println(io, ",")
#       indent(io)
#       show(io, arg)
#     end
#     println(io)
#   end
#   indent(io)
#   print(io, stop)
# end
#
# show_args(io::IO, args::Node...) = begin
#   :if(length(args) == 0, begin
#     return nothing
#   end)
#   :if(length(args) == 1, begin
#     show(io, args[1])
#     return nothing
#   end)
#   show(io, [args...])
# end
#
# show_div(io::IO, expr::BasicExpr{T}) where {T} = begin
#   args = expr.args
#   :if(length(args) > 1, begin
#     show(io, args[1])
#     args = args[2:end]
#   end)
#   print(io, T)
#   show_args(io, args...)
# end
#
# show_block(io::IO, blk::BasicExpr{:block}) = begin
#   println(io)
#   indent(io) do io::IO
#     for arg = blk.args
#       indent(io)
#       show(io, arg)
#       println(io)
#     end
#   end
#   indent(io)
#   print(io, "end")
# end
#
# show_vect(io::IO, args::Vector) = begin
#   print(io, "[")
#   show_args(io, args...)
#   print(io, "]")
# end
#
# show_infix(
#   io::IO,
#   head::Any,
#   args::Vector
# ) = begin
#   show(io, args[1])
#   print(
#     io,
#     " ",
#     head,
#     " "
#   )
#   show_args(io, args[2:end]...)
# end
#
# show(io::IO, node::QuoteExpr) = begin
#   show(io, node.val)
# end
#
# show(io::IO, expr::ValExpr) = begin
#   show(io, expr.val)
# end
#
# show(io::IO, expr::SymbolExpr{T}) where {T} = begin
#   print(io, T)
# end
#
# show(io::IO, expr::BasicExpr{T}) where {T} = begin
#   show(io, T)
#   args = [arg for arg = expr.args if !isa(arg, LineNumberNode)]
#   show(io, args)
# end
#
# show(io::IO, expr::BasicExpr{:block}) = begin
#   println(io, "begin")
#   indent(io) do io::IO
#     for arg = expr.args
#       indent(io)
#       show(io, arg)
#       println(io)
#     end
#   end
#   indent(io)
#   print(io, "end")
# end
#
# show(io::IO, expr::InfixExpr{T}) where {T} = begin
#   show_infix(
#     io,
#     T,
#     expr.args
#   )
# end
#
# show(io::IO, expr::CallExpr) = begin
#   show(io, expr.head)
#   args = expr.args
#   kwargs = nothing
#   :if(length(args) > 0 && isa(args[1], BasicExpr{:parameters}), begin
#     kwargs = args[1].args
#     args = args[2:end]
#   end)
#   print(io, '(')
#   show(io, args; start="", stop="")
#   :if(kwargs !== nothing, begin
#     print(io, "; ")
#     show(io, kwargs; start="", stop="")
#   end)
#   print(io, ')')
# end
#
# show(io::IO, expr::CallExpr{:(:)}) = begin
#   args = expr.args
#   :if(length(args) == 0, begin
#     args = expr.args[:]
#     print(io, ":")
#     return nothing
#   end)
#   show(io, args[1])
#   print(io, ":")
#   show_args(io, args[2:end]...)
# end
#
# show(io::IO, expr::CallExpr{:!}) = begin
#   print(io, "!")
#   show_args(io, expr.args...)
# end
#
# show(io::IO, expr::BasicExpr{:(::)}) = begin
#   show_div(io, expr)
# end
#
# show(io::IO, expr::BasicExpr{:curly}) = begin
#   show(io, expr.args[1])
#   show(io, expr.args[2:end]; start='{', stop='}')
# end
#
# show(io::IO, expr::BasicExpr{:where}) = begin
#   show(io, expr.args[1])
#   print(io, " where ")
#   show(io, expr.args[2:end]; start='{', stop='}')
# end
#
# show(io::IO, expr::BasicExpr{:function}) = begin
#   print(io, "function ")
#   show(io, expr.args[1])
#   show_block(io, expr.args[2])
# end
#
# show(io::IO, expr::BasicExpr{:.}) = begin
#   args = expr.args
#   :macrocall(@assert, length(args) == 2)
#   show(io, args[1])
#   print(io, ".")
#   node = args[2]
#   :if(isa(node, QuoteExpr), begin
#     args[2] = parse(node.val)
#   end)
#   show(io, args[2])
# end
#
# show(io::IO, expr::BasicExpr{:...}) = begin
#   args = expr.args
#   :macrocall(@assert, length(args) == 1)
#   show(io, args[1])
#   print(io, "...")
# end
#
# show(io::IO, expr::BasicExpr{:ref}) = begin
#   args = expr.args
#   :macrocall(@assert, length(args) == 2)
#   show(io, args[1])
#   print(io, "[")
#   show(io, args[2])
#   print(io, "]")
# end
#
# show(io::IO, expr::BasicExpr{:vect}) = begin
#   show_vect(io, expr.args)
# end
#
# show(io::IO, expr::BasicExpr{:return}) = begin
#   print(io, "return ")
#   show_args(io, expr.args...)
# end
#
# show(io::IO, expr::BasicExpr{:do}) = begin
#   args = expr.args
#   :macrocall(@assert, length(args) == 2)
#   show(io, args[1])
#   print(io, " do ")
#   show(io, args[2])
# end
#
# show(io::IO, expr::BasicExpr{:->}) = begin
#   args = expr.args
#   :macrocall(@assert, length(args) == 2)
#   arg = args[1]
#   :if(isa(arg, BasicExpr{:tuple}), begin
#     show_args(io, arg.args...)
#     arg = nothing
#   end)
#   :if(arg !== nothing, begin
#     show(io, arg)
#   end)
#   show_block(io, args[2])
# end
#
# show(io::IO, expr::BasicExpr{:tuple}) = begin
#   args = expr.args
#   :if(length(args) > 1, begin
#     show(io, args)
#     return nothing
#   end)
#   print(io, "(")
#   for arg = args
#     show(io, arg)
#     print(io, ",")
#   end
#   print(io, ")")
# end
#
# show(io::IO, expr::BasicExpr{:for}) = begin
#   args = expr.args
#   print(io, "for ")
#   show(io, args[1])
#   show_block(io, args[2])
# end
#
# show(io::IO, expr::BasicExpr{:comprehension}) = begin
#   show_vect(io, expr.args)
# end
#
# show(io::IO, expr::BasicExpr{:generator}) = begin
#   args = expr.args
#   show(io, args[1])
#   print(io, " for ")
#   show_args(io, args[2:end]...)
# end
#
# show(io::IO, expr::BasicExpr{:filter}) = begin
#   args = expr.args
#   :macrocall(@assert, length(args) == 2)
#   show(io, args[2])
#   print(io, " if ")
#   show(io, args[1])
# end
#
# show(io::IO, expr::BasicExpr{:abstract}) = begin
#   print(io, "abstract type ")
#   show_args(io, expr.args...)
#   println(io)
#   print(io, "end")
# end
#
# show(io::IO, expr::BasicExpr{:struct}) = begin
#   args = expr.args
#   :macrocall(@assert, length(args) == 3)
#   mu = args[1]::ValExpr{Bool}
#   :if(mu.val, begin
#     print(io, "mutable ")
#   end)
#   print(io, "struct ")
#   show(io, args[2])
#   show_block(io, args[3])
# end
#
# show(io::IO, expr::BasicExpr{:kw}) = begin
#   args = expr.args
#   :macrocall(@assert, length(args) == 2)
#   show(io, args[1])
#   print(io, "=")
#   show(io, args[2])
# end
#
# show(io::IO, expr::BasicExpr{:<:}) = begin
#   :if(length(expr.args) <= 1, begin
#     show_div(io, expr)
#     return nothing
#   end)
#   show_infix(
#     io,
#     :<:,
#     expr.args
#   )
# end
#
# show(io::IO, expr::BasicExpr{:>:}) = begin
#   :if(length(expr.args) <= 1, begin
#     show_div(io, expr)
#     return nothing
#   end)
#   show_infix(
#     io,
#     :>:,
#     expr.args
#   )
# end
#
# show(io::IO, expr::BasicExpr{:(=)}) = begin
#   :if(length(expr.args) <= 1, begin
#     show_div(io, expr)
#     return nothing
#   end)
#   show_infix(
#     io,
#     :(=),
#     expr.args
#   )
# end
#
# show(io::IO, expr::BasicExpr{:&&}) = begin
#   :if(length(expr.args) <= 1, begin
#     show_div(io, expr)
#     return nothing
#   end)
#   show_infix(
#     io,
#     :&&,
#     expr.args
#   )
# end
#
# show(io::IO, expr::BasicExpr{:||}) = begin
#   :if(length(expr.args) <= 1, begin
#     show_div(io, expr)
#     return nothing
#   end)
#   show_infix(
#     io,
#     :||,
#     expr.args
#   )
# end
